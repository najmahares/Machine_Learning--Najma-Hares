# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

df = pd.read_csv('Titanic-Cleaned.csv')

df['Age'] = df['Age'].fillna(df['Age'].median())
df['Fare'] = df['Fare'].fillna(df['Fare'].median())
df['Sex'] = df['Sex'].map({'female': 0, 'male': 1})

df['Age'] = df['Age'].astype(int)
df['Fare'] = df['Fare'].astype(int)

features = ['Pclass', 'Sex', 'Age', 'Fare']
X = df[features]
y = df['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

model = MultinomialNB()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
print(f"Real Titanic Model Accuracy: {accuracy_score(y_test, predictions) * 100:.2f}%")

results_df = X_test.copy()
results_df['Actual_Survived'] = y_test
results_df['Predicted_Survived'] = predictions

results_df.head(10)
# Out:
# Real Titanic Model Accuracy: 72.07%
#      Pclass  Sex  Age  Fare  Actual_Survived  Predicted_Survived
# 709       3    1   28    15                1                   0
# 439       2    1   31    10                0                   0
# 840       3    1   20     7                0                   0
# 720       2    0    6    33                1                   1
# 39        3    0   14    11                1                   0
# 290       1    0   26    78                1                   1
# 300       3    0   28     7                1                   0
# 333       3    1   16    18                0                   0
# 208       3    0   16     7                1                   0
# 136       1    0   19    26                1                   1
